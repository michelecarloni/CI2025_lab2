# %%
import math
from itertools import combinations
import numpy as np
import random
from Problem import Problem
from utils_main import *
from algorithms import *

# %% [markdown]
# GOAL
# Cost minimization

# %% [markdown]
# ## Simple Test Problem

# %%
CITIES = [
    "Rome",
    "Milan",
    "Naples",
    "Turin",
    "Palermo",
    "Genoa",
    "Bologna",
    "Florence",
    "Bari",
    "Catania",
    "Venice",
    "Verona",
    "Messina",
    "Padua",
    "Trieste",
    "Taranto",
    "Brescia",
    "Prato",
    "Parma",
    "Modena",
]
test_problem = np.load('problems/test_problem.npy')

# %% [markdown]
# ### LOAD PROBLEMS

# %%
g_10 = Problem("g_10", np.load('problems/problem_g_10.npy'))
g_20 = Problem("g_20", np.load('problems/problem_g_20.npy'))
g_50 = Problem("g_50", np.load('problems/problem_g_50.npy'))
g_100 = Problem("g_100", np.load('problems/problem_g_100.npy'))
g_200 = Problem("g_200", np.load('problems/problem_g_200.npy'))
g_500 = Problem("g_500", np.load('problems/problem_g_500.npy'))
g_1000 = Problem("g_1000", np.load('problems/problem_g_1000.npy'))

r1_10 = Problem("r1_10", np.load('problems/problem_r1_10.npy'))
r1_20 = Problem("r1_20", np.load('problems/problem_r1_20.npy'))
r1_50 = Problem("r1_50", np.load('problems/problem_r1_50.npy'))
r1_100 = Problem("r1_100", np.load('problems/problem_r1_100.npy'))
r1_200 = Problem("r1_200", np.load('problems/problem_r1_200.npy'))
r1_500 = Problem("r1_500", np.load('problems/problem_r1_500.npy'))
r1_1000 = Problem("r1_1000", np.load('problems/problem_r1_1000.npy'))

r2_10 = Problem("r2_10", np.load('problems/problem_r2_10.npy'))
r2_20 = Problem("r2_20", np.load('problems/problem_r2_20.npy'))
r2_50 = Problem("r2_50", np.load('problems/problem_r2_50.npy'))
r2_100 = Problem("r2_100", np.load('problems/problem_r2_100.npy'))
r2_200 = Problem("r2_200", np.load('problems/problem_r2_200.npy'))
r2_500 = Problem("r2_500", np.load('problems/problem_r2_500.npy'))
r2_1000 = Problem("r2_1000", np.load('problems/problem_r2_1000.npy'))



# DEFINE ARRAY FOR HANDLE ALL THE PROBLEMS

problems_arr = [g_10, g_20, g_50, g_100, g_200, g_500, g_1000,
                r1_10, r1_20, r1_50, r1_100, r1_200, r1_500, r1_1000,
                r2_10, r2_20, r2_50, r2_100, r2_200, r2_500, r2_1000]

# %%
# TEST OF PROBLEMS' CHARACTERISTIC


print(f"check negative value | g_100: {check_negative_value(g_100.distance_matrix)}")
print(f"check diagonal all 0s | g_100: {check_diagonal_all_zero(g_100.distance_matrix)}")
print(f"check symmetry | g_100: {check_symmetry(g_100.distance_matrix)}")
print(f"check triangular inequality | g_100 {check_triangular_inequality(g_100.distance_matrix)}")
print()
print(f"check negative value | r1_100: {check_negative_value(r1_100.distance_matrix)}")
print(f"check diagonal all 0s | r1_100: {check_diagonal_all_zero(r1_100.distance_matrix)}")
print(f"check symmetry | r1_100: {check_symmetry(r1_100.distance_matrix)}")
print(f"check triangular inequality | r1_100 {check_triangular_inequality(r1_100.distance_matrix)}")
print()
print(f"check negative value | r2_100: {check_negative_value(r2_100.distance_matrix)}")
print(f"check diagonal all 0s | r2_100: {check_diagonal_all_zero(r2_100.distance_matrix)}")
print(f"check symmetry | r2_100: {check_symmetry(r2_100.distance_matrix)}")
print(f"check triangular inequality | r2_100 {check_triangular_inequality(r2_100.distance_matrix)}")
print()
# Out:
# check negative value | g_100: False
# check diagonal all 0s | g_100: True
# check symmetry | g_100: True
# check triangular inequality | g_100 True
#
# check negative value | r1_100: False
# check diagonal all 0s | r1_100: True
# check symmetry | r1_100: False
# check triangular inequality | r1_100 False
#
# check negative value | r2_100: True
# check diagonal all 0s | r2_100: False
# check symmetry | r2_100: False
# check triangular inequality | r2_100 False

# %%
# HYPERPARAMETERS (for algo_1)

POPULATION_SIZE = 100
NUM_GENERATIONS = 1000
ELITISM_SIZE = 2
TOURNAMENT_K = 3
CROSSOVER_RATE = 0.9
MUTATION_RATE = 0.2

# HYPERPARAMETERS (for simulated_annealing)
INITIAL_TEMPERATURE = 1000.0
COOLING_RATE = 0.995
SA_ITERATIONS = 10000

# HYPERPARAMETERS (for algo_3)
TS_ITERATIONS = 10000
TABU_TENURE = 30         
NEIGHBORHOOD_SIZE = 50

# %% [markdown]
# ### RESULTS

# %%
for problem in problems_arr:

    best_tour, best_fitness, _ = algo_1(
        problem=problem,
        pop_size=POPULATION_SIZE,
        num_generations=NUM_GENERATIONS,
        elitism_size=ELITISM_SIZE,
        k=TOURNAMENT_K,
        crossover_rate=CROSSOVER_RATE,
        mutation_rate=MUTATION_RATE,
        show_process=False
    )

    #print(f"{problem.name} | Best tour: {best_tour}")
    print(f"{problem.name} | Total fitness: {best_fitness:.2f}\n")
# Out:
# g_10 | Running...
# g_10 | Total fitness: 1497.66
#
# g_20 | Running...
# g_20 | Total fitness: 1755.51
#
# g_50 | Running...
# g_50 | Total fitness: 2771.26
#
# g_100 | Running...
# g_100 | Total fitness: 4424.08
#
# g_200 | Running...
# g_200 | Total fitness: 8913.38
#
# g_500 | Running...
# g_500 | Total fitness: 36002.08
#
# g_1000 | Running...
# g_1000 | Total fitness: 99748.92
#
# r1_10 | Running...
# r1_10 | Total fitness: 184.27
#
# r1_20 | Running...
# r1_20 | Total fitness: 364.84
#
# r1_50 | Running...
# r1_50 | Total fitness: 878.75
#
# r1_100 | Running...
# r1_100 | Total fitness: 1854.76
#
# r1_200 | Running...
# r1_200 | Total fitness: 4436.31
#
# r1_500 | Running...
# r1_500 | Total fitness: 15056.19
#
# r1_1000 | Running...
# r1_1000 | Total fitness: 35403.57
#
# r2_10 | Running...
# r2_10 | Total fitness: -411.70
#
# r2_20 | Running...
# r2_20 | Total fitness: -656.73
#
# r2_50 | Running...
# r2_50 | Total fitness: -1641.51
#
# r2_100 | Running...
# r2_100 | Total fitness: -2934.03
#
# r2_200 | Running...
# r2_200 | Total fitness: -5934.63
#
# r2_500 | Running...
# r2_500 | Total fitness: -11269.19
#
# r2_1000 | Running...
# r2_1000 | Total fitness: -17285.53

# %%
for problem in problems_arr:

    best_tour, best_fitness, _ = simulated_annealing(
        problem=problem,
        initial_temp=INITIAL_TEMPERATURE,
        cooling_rate=COOLING_RATE,
        num_iterations=SA_ITERATIONS,
        show_process=False
    )


    #print(f"{problem.name} | Best tour: {best_tour}")
    print(f"{problem.name} | Total fitness: {best_fitness:.2f}\n")
# Out:
# g_10 | Running SA...
# g_10 | Total fitness: 1497.66
#
# g_20 | Running SA...
# g_20 | Total fitness: 1809.41
#
# g_50 | Running SA...
# g_50 | Total fitness: 2679.18
#
# g_100 | Running SA...
# g_100 | Total fitness: 4760.07
#
# g_200 | Running SA...
# g_200 | Total fitness: 10520.38
#
# g_500 | Running SA...
# g_500 | Total fitness: 36490.32
#
# g_1000 | Running SA...
# g_1000 | Total fitness: 95520.00
#
# r1_10 | Running SA...
# r1_10 | Total fitness: 190.60
#
# r1_20 | Running SA...
# r1_20 | Total fitness: 343.76
#
# r1_50 | Running SA...
# r1_50 | Total fitness: 991.67
#
# r1_100 | Running SA...
# r1_100 | Total fitness: 1749.82
#
# r1_200 | Running SA...
# r1_200 | Total fitness: 5276.71
#
# r1_500 | Running SA...
# r1_500 | Total fitness: 18836.01
#
# r1_1000 | Running SA...
# r1_1000 | Total fitness: 43177.41
#
# r2_10 | Running SA...
# r2_10 | Total fitness: -332.54
#
# r2_20 | Running SA...
# r2_20 | Total fitness: -599.53
#
# r2_50 | Running SA...
# r2_50 | Total fitness: -1408.07
#
# r2_100 | Running SA...
# r2_100 | Total fitness: -2558.73
#
# r2_200 | Running SA...
# r2_200 | Total fitness: -3753.94
#
# r2_500 | Running SA...
# r2_500 | Total fitness: -6880.43
#
# r2_1000 | Running SA...
# r2_1000 | Total fitness: -7970.09

# %%
for problem in problems_arr:
    
    best_tour, best_fitness, _ = tabu_search(
        problem=problem,
        num_iterations=TS_ITERATIONS,
        tabu_tenure=TABU_TENURE,
        neighborhood_size=NEIGHBORHOOD_SIZE,
        show_process=False
    )

    #print(f"{problem.name} | Best tour: {best_tour}")
    print(f"{problem.name} | Total fitness: {best_fitness:.2f}\n")
# Out:
# g_10 | Running Tabu Search...
# g_10 | Total fitness: 1497.66
#
# g_20 | Running Tabu Search...
# g_20 | Total fitness: 1755.51
#
# g_50 | Running Tabu Search...
# g_50 | Total fitness: 2721.98
#
# g_100 | Running Tabu Search...
# g_100 | Total fitness: 4824.16
#
# g_200 | Running Tabu Search...
# g_200 | Total fitness: 8599.72
#
# g_500 | Running Tabu Search...
# g_500 | Total fitness: 20347.14
#
# g_1000 | Running Tabu Search...
# g_1000 | Total fitness: 40955.33
#
# r1_10 | Running Tabu Search...
# r1_10 | Total fitness: 184.27
#
# r1_20 | Running Tabu Search...
# r1_20 | Total fitness: 337.29
#
# r1_50 | Running Tabu Search...
# r1_50 | Total fitness: 674.00
#
# r1_100 | Running Tabu Search...
# r1_100 | Total fitness: 1331.19
#
# r1_200 | Running Tabu Search...
# r1_200 | Total fitness: 3974.56
#
# r1_500 | Running Tabu Search...
# r1_500 | Total fitness: 14161.68
#
# r1_1000 | Running Tabu Search...
# r1_1000 | Total fitness: 34322.40
#
# r2_10 | Running Tabu Search...
# r2_10 | Total fitness: -411.70
#
# r2_20 | Running Tabu Search...
# r2_20 | Total fitness: -809.78
#
# r2_50 | Running Tabu Search...
# r2_50 | Total fitness: -1666.19
#
# r2_100 | Running Tabu Search...
# r2_100 | Total fitness: -2849.01
#
# r2_200 | Running Tabu Search...
# r2_200 | Total fitness: -4715.44
#
# r2_500 | Running Tabu Search...
# r2_500 | Total fitness: -8422.38
#
# r2_1000 | Running Tabu Search...
# r2_1000 | Total fitness: -12238.87
